# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import datetime as dt

# %%
data=pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition (1).csv")

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
data.shape
# Out:
# (1470, 35)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe(include='all')
# Out:
#                 Age Attrition BusinessTravel    DailyRate  \
# count   1470.000000      1470           1470  1470.000000
# unique          NaN         2              3          NaN
# top             NaN        No  Travel_Rarely          NaN
# freq            NaN      1233           1043          NaN
# mean      36.923810       NaN            NaN   802.485714
# std        9.135373       NaN            NaN   403.509100
# min       18.000000       NaN            NaN   102.000000
# 25%       30.000000       NaN            NaN   465.000000
# 50%       36.000000       NaN            NaN   802.000000
# 75%       43.000000       NaN            NaN  1157.000000
# max       60.000000       NaN            NaN  1499.000000
#
#                     Department  DistanceFromHome    Education EducationField  \
# count                     1470       1470.000000  1470.000000           1470
# unique                       3               NaN          NaN              6
# ...

# %%
for col in data.describe(include= 'object').columns:
  print(col)
  print(data[col].unique())
  print('-'*50)
# Out:
# Attrition
# ['Yes' 'No']
# --------------------------------------------------
# BusinessTravel
# ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# --------------------------------------------------
# Department
# ['Sales' 'Research & Development' 'Human Resources']
# --------------------------------------------------
# EducationField
# ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# --------------------------------------------------
# Gender
# ['Female' 'Male']
# --------------------------------------------------
# JobRole
# ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
# --------------------------------------------------
# MaritalStatus
# ['Single' 'Married' 'Divorced']
# --------------------------------------------------
# Over18
# ['Y']
# --------------------------------------------------
# ...

# %%
for col in data.describe(include= 'all').columns:
  print(col)
  print(data[col].unique())
  print('-'*50)
# Out:
# Age
# [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
# --------------------------------------------------
# Attrition
# ['Yes' 'No']
# --------------------------------------------------
# BusinessTravel
# ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# --------------------------------------------------
# DailyRate
# [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
#   853 1142  655 1115  427  653  989 1435 1223  836 1195 1339  664  318
#  1225 1328 1082  548  132  746  776  193  397  945 1214  111  573 1153
#  1400  541  432  288  669  530  632 1334  638 1093 1217 1353  120  682
#   489  807  827  871  665 1040 1420  240 1280  534 1456  658  142 1127
# ...

# %%
data.groupby(['Gender', 'Attrition'])['EmployeeNumber'].count().unstack().plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
data.groupby(['Gender', 'Attrition'])['EmployeeNumber'].count()
# Out:
# Gender  Attrition
# Female  No           501
#         Yes           87
# Male    No           732
#         Yes          150
# Name: EmployeeNumber, dtype: int64

# %%
data.groupby(['BusinessTravel', 'Attrition'])['EmployeeNumber'].count()
# Out:
# BusinessTravel     Attrition
# Non-Travel         No           138
#                    Yes           12
# Travel_Frequently  No           208
#                    Yes           69
# Travel_Rarely      No           887
#                    Yes          156
# Name: EmployeeNumber, dtype: int64

# %%
data.groupby(['BusinessTravel', 'Attrition'])['EmployeeNumber'].count().unstack().plot(kind='bar')
# Out:
# <Axes: xlabel='BusinessTravel'>

# %%
data.groupby(['Department', 'Attrition'])['EmployeeNumber'].count()
# Out:
# Department              Attrition
# Human Resources         No            51
#                         Yes           12
# Research & Development  No           828
#                         Yes          133
# Sales                   No           354
#                         Yes           92
# Name: EmployeeNumber, dtype: int64

# %%
total = data.groupby('Department')['Attrition'].count().reset_index().sort_values('Attrition', ascending=False)
p1=sns.barplot(data=total, x='Department', y='Attrition')
p1.bar_label(p1.containers[0])
plt.title('Top departments of attritions')
plt.xticks(rotation=0)
plt.show()

# %%
data.groupby('JobRole')['Attrition'].count()
# Out:
# JobRole
# Healthcare Representative    131
# Human Resources               52
# Laboratory Technician        259
# Manager                      102
# Manufacturing Director       145
# Research Director             80
# Research Scientist           292
# Sales Executive              326
# Sales Representative          83
# Name: Attrition, dtype: int64

# %%
total = data.groupby('JobRole')['Attrition'].count().reset_index().sort_values('Attrition', ascending=False)
p1=sns.barplot(data=total, x='JobRole', y='Attrition')
p1.bar_label(p1.containers[0])
plt.title('Top job roles of attritions')
plt.xticks(rotation=90)
plt.show()

# %%
sns.kdeplot(data, x="MonthlyIncome",hue="Attrition",fill=True, common_norm=False)
# Out:
# <Axes: xlabel='MonthlyIncome', ylabel='Density'>

# %%
# Generate histograms for all numeric columns
data.hist(figsize=(20,15), color='Green')
plt.tight_layout()
plt.show()

# %%
sns.boxplot(data=data,x='JobSatisfaction', y='Age', hue='Attrition')
# Out:
# <Axes: xlabel='JobSatisfaction', ylabel='Age'>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# label encode the data
le = LabelEncoder()
data['BusinessTravel'] = le.fit_transform(data['BusinessTravel'])
data['Attrition'] = le.fit_transform(data['Attrition'])
data['OverTime'] = le.fit_transform(data['OverTime'])
data['Gender'] = le.fit_transform(data['Gender'])
data['MaritalStatus'] = le.fit_transform(data['MaritalStatus'])
data['Department'] = le.fit_transform(data['Department'])
data['EducationField'] = le.fit_transform(data['EducationField'])
data['JobRole'] = le.fit_transform(data['JobRole'])
data['Over18'] = le.fit_transform(data['Over18'])

# %%
data.drop(['MonthlyIncome' ,'YearsInCurrentRole' , 'YearsAtCompany', 'YearsWithCurrManager'],axis=1,inplace=True)

# %%
data.head(10)
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
# 5   32          0               1       1005           1                 2
# 6   59          0               2       1324           1                 3
# 7   30          0               2       1358           1                24
# 8   38          0               1        216           1                23
# 9   36          0               2       1299           1                27
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  OverTime  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int32
#  2   BusinessTravel            1470 non-null   int32
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   int32
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   int32
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   int32
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
#normalizing 
from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler(feature_range = (0,1))
DF1 = data.drop(columns=['Attrition'])
norm = scaler.fit_transform(data)
norm_df = pd.DataFrame(norm,columns=data.columns)

# %%
X = pd.DataFrame(norm_df.drop(columns='Attrition'))
Y = pd.DataFrame(norm_df.Attrition).values.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train  , x_test , y_train, y_test = train_test_split (X ,Y ,test_size = 0.2 , random_state = 0)

# %%
pip install imblearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# #SMOTE
# from imblearn.over_sampling import SMOTE
# oversampler=SMOTE(random_state=0)
# smote_train, smote_target = oversampler.fit_resample(x_train,y_train)

# %%
from sklearn import metrics

# %%
from sklearn.linear_model import LogisticRegression

log_reg=LogisticRegression(C=1000,max_iter=10000)
log_reg.fit(x_train, y_train)
y_pred_lg = log_reg.predict(x_test)

print ('accuracy',metrics.accuracy_score(y_test, y_pred_lg))
# Out:
# accuracy 0.8707482993197279
# C:\Users\Dell\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
print(metrics.classification_report(y_test, y_pred_lg))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.98      0.93       245
#          1.0       0.74      0.35      0.47        49
#
#     accuracy                           0.87       294
#    macro avg       0.81      0.66      0.70       294
# weighted avg       0.86      0.87      0.85       294

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()
rfc = rfc.fit(x_train, y_train)
y_pred = rfc.predict(x_test)

print ('accuracy',metrics.accuracy_score(y_test, y_pred))
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_13060\475572435.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfc = rfc.fit(x_train, y_train)
# accuracy 0.8571428571428571

# %%
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.99      0.92       245
#          1.0       0.82      0.18      0.30        49
#
#     accuracy                           0.86       294
#    macro avg       0.84      0.59      0.61       294
# weighted avg       0.85      0.86      0.82       294

# %%
from sklearn.ensemble import  GradientBoostingClassifier

gb = GradientBoostingClassifier()
gb.fit(x_train, y_train)

gb_predictions = gb.predict(x_test)
print('accuracy',metrics.accuracy_score(y_test, gb_predictions))
# Out:
# C:\Users\Dell\AppData\Roaming\Python\Python311\site-packages\sklearn\ensemble\_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# accuracy 0.8537414965986394

# %%
print(metrics.classification_report(y_test, gb_predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.98      0.92       245
#          1.0       0.69      0.22      0.34        49
#
#     accuracy                           0.85       294
#    macro avg       0.78      0.60      0.63       294
# weighted avg       0.83      0.85      0.82       294

# %% [markdown]
# # Thank You !!
